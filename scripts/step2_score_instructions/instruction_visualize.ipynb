# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.append(str(Path("../../src").resolve()))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils.parser import load_jsonl, save_jsonl 

# score_path = "../../scripts/step2_score_instructions/outputs/instructions_score.gpt-4-0314.1000.txt"
# score_path = "../../scripts/step2_score_instructions/outputs/instructions.gpt-4-0314.1000.score.gpt-35-turbo-0301.txt"
score_path = "../../scripts/step2_score_instructions/outputs/instructions.gpt-4-0314.1000.score.llama-2-7b-chat.txt"
score_path = "../../scripts/step2_score_instructions/outputs/instructions.gpt-4-0314.1000.score.llama-2-70b-chat.txt"
model_name = "llama-2-chat-70B"

score_list = load_jsonl(score_path)
score_list = [e["score"] for e in score_list]
print(len(score_list))
print(score_list[:10])

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
# plot histogram bin range 0, 1, 2, 3, 4, 5
fig = plt.figure(figsize=(10, 5))
ax = sns.histplot(score_list, bins=6, binrange=(0, 5), discrete=True)
# log scale
# ax.set_yscale('log')
plt.title(f"Scroing instruction using {model_name}")
plt.xlabel("Score")
plt.ylim(0, 80)
plt.plot()
# Out:
# 100
# [2, 5, 4, 5, 5, 5, 5, 4, 5, 5]
# []
